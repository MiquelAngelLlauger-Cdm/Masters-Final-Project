# %% [markdown]
# ## 1. Load graph

# %%
import sys, networkx as nx
sys.path.insert(0, "..")   # make models/ importable

G = nx.read_graphml("../graphs/w8/a/att_density8_a.graphml")
print(f"Nodes: {G.number_of_nodes()}  Edges: {G.number_of_edges()}")
# Out:
# Nodes: 554  Edges: 2236

# %% [markdown]
# ## 2. Train GCN

# %%
from models.gnn import run

model, data = run(
    G,
    epochs   = 300,
    lr       = 0.05,
    hidden   = 64,
    dropout  = 0.5,
    device   = "cpu",
)
# Out:
# GCN  |  nodes=554  train=354  val=89  test=111
#   epoch   1  train_loss=0.7041  val_loss=0.6388  val_acc=0.663
#   epoch  50  train_loss=0.5253  val_loss=0.4640  val_acc=0.764
#   epoch 100  train_loss=0.5333  val_loss=0.4431  val_acc=0.764
#   epoch 150  train_loss=0.5171  val_loss=0.4530  val_acc=0.764
#   epoch 200  train_loss=0.5370  val_loss=0.4593  val_acc=0.764
#   epoch 250  train_loss=0.5303  val_loss=0.4769  val_acc=0.764
#   epoch 300  train_loss=0.5473  val_loss=0.4473  val_acc=0.764
#
# Test acc: 0.784
#
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.96      0.67      0.79        67
#        Completed (tier 4)       0.66      0.95      0.78        44
#
#                  accuracy                           0.78       111
#                 macro avg       0.81      0.81      0.78       111
#              weighted avg       0.84      0.78      0.78       111

# %% [markdown]
# ## 5. 5-fold cross-validation

# %%
from models.gnn import cross_validate

cv_results = cross_validate(
    G,
    k         = 5,
    epochs    = 200,
    lr        = 0.01,
    hidden    = 32,
    dropout   = 0.5,
    device    = "cpu",
)
# Out:
# ── Fold 1/5  train=443  test=111
#   epoch   1  train_loss=0.7126
#   epoch  20  train_loss=0.5331
#   epoch  40  train_loss=0.5065
#   epoch  60  train_loss=0.5297
#   epoch  80  train_loss=0.5079
#   epoch 100  train_loss=0.4961
#   epoch 120  train_loss=0.4877
#   epoch 140  train_loss=0.4927
#   epoch 160  train_loss=0.5071
#   epoch 180  train_loss=0.5084
#   epoch 200  train_loss=0.5151
#   → test_acc=0.766  test_f1=0.766
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.98      0.62      0.76        66
#        Completed (tier 4)       0.64      0.98      0.77        45
#
#                  accuracy                           0.77       111
#                 macro avg       0.81      0.80      0.77       111
#              weighted avg       0.84      0.77      0.76       111
#
#
# ── Fold 2/5  train=443  test=111
#   epoch   1  train_loss=0.7175
#   epoch  20  train_loss=0.5460
#   epoch  40  train_loss=0.5056
#   epoch  60  train_loss=0.4930
#   epoch  80  train_loss=0.4915
#   epoch 100  train_loss=0.4856
#   epoch 120  train_loss=0.4774
#   epoch 140  train_loss=0.4819
#   epoch 160  train_loss=0.4947
#   epoch 180  train_loss=0.4784
#   epoch 200  train_loss=0.4845
#   → test_acc=0.685  test_f1=0.684
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.90      0.54      0.67        67
#        Completed (tier 4)       0.56      0.91      0.70        44
#
#                  accuracy                           0.68       111
#                 macro avg       0.73      0.72      0.68       111
#              weighted avg       0.77      0.68      0.68       111
#
#
# ── Fold 3/5  train=443  test=111
#   epoch   1  train_loss=0.7021
#   epoch  20  train_loss=0.5310
#   epoch  40  train_loss=0.5002
#   epoch  60  train_loss=0.4799
#   epoch  80  train_loss=0.4960
#   epoch 100  train_loss=0.4705
#   epoch 120  train_loss=0.4762
#   epoch 140  train_loss=0.4788
#   epoch 160  train_loss=0.4757
#   epoch 180  train_loss=0.4836
#   epoch 200  train_loss=0.4902
#   → test_acc=0.667  test_f1=0.666
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.89      0.51      0.65        67
#        Completed (tier 4)       0.55      0.91      0.68        44
#
#                  accuracy                           0.67       111
#                 macro avg       0.72      0.71      0.67       111
#              weighted avg       0.76      0.67      0.66       111
#
#
# ── Fold 4/5  train=443  test=111
#   epoch   1  train_loss=0.7087
#   epoch  20  train_loss=0.5175
#   epoch  40  train_loss=0.5104
#   epoch  60  train_loss=0.5009
#   epoch  80  train_loss=0.5097
#   epoch 100  train_loss=0.4992
#   epoch 120  train_loss=0.4862
#   epoch 140  train_loss=0.5002
#   epoch 160  train_loss=0.4976
#   epoch 180  train_loss=0.4964
#   epoch 200  train_loss=0.4971
#   → test_acc=0.757  test_f1=0.757
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.95      0.63      0.76        67
#        Completed (tier 4)       0.63      0.95      0.76        44
#
#                  accuracy                           0.76       111
#                 macro avg       0.79      0.79      0.76       111
#              weighted avg       0.82      0.76      0.76       111
#
#
# ── Fold 5/5  train=444  test=110
#   epoch   1  train_loss=0.6998
#   epoch  20  train_loss=0.5233
#   epoch  40  train_loss=0.5154
#   epoch  60  train_loss=0.5143
#   epoch  80  train_loss=0.4991
#   epoch 100  train_loss=0.5183
#   epoch 120  train_loss=0.5062
#   epoch 140  train_loss=0.5033
#   epoch 160  train_loss=0.4990
#   epoch 180  train_loss=0.5011
#   epoch 200  train_loss=0.5064
#   → test_acc=0.800  test_f1=0.800
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.96      0.70      0.81        66
#        Completed (tier 4)       0.68      0.95      0.79        44
#
#                  accuracy                           0.80       110
#                 macro avg       0.82      0.83      0.80       110
#              weighted avg       0.85      0.80      0.80       110
#
#
# ────────────────────────────────────────
#   Fold   Test acc    Test F1
#      1      0.766      0.766
#      2      0.685      0.684
#      3      0.667      0.666
#      4      0.757      0.757
#      5      0.800      0.800
#   Mean      0.735      0.734
#    Std      0.051      0.051

# %%
G12 = nx.read_graphml("../graphs/w12/a/att_density12_a.graphml")
print(f"Nodes: {G12.number_of_nodes()}  Edges: {G12.number_of_edges()}")
# Out:
# Nodes: 554  Edges: 3256

# %%
cv_results = cross_validate(
    G12,
    k=5, 
    epochs=250, 
    lr=0.01, 
    hidden=32, 
    dropout=0.5, 
    device="cpu"
)
# Out:
# ── Fold 1/5  train=443  test=111
#   epoch   1  train_loss=0.7121
#   epoch  20  train_loss=0.4657
#   epoch  40  train_loss=0.4046
#   epoch  60  train_loss=0.3878
#   epoch  80  train_loss=0.4010
#   epoch 100  train_loss=0.3947
#   epoch 120  train_loss=0.3915
#   epoch 140  train_loss=0.4048
#   epoch 160  train_loss=0.3998
#   epoch 180  train_loss=0.3887
#   epoch 200  train_loss=0.3852
#   epoch 220  train_loss=0.3975
#   epoch 240  train_loss=0.3736
#   → test_acc=0.784  test_f1=0.784
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       1.00      0.64      0.78        66
#        Completed (tier 4)       0.65      1.00      0.79        45
#
#                  accuracy                           0.78       111
#                 macro avg       0.83      0.82      0.78       111
#              weighted avg       0.86      0.78      0.78       111
#
#
# ── Fold 2/5  train=443  test=111
#   epoch   1  train_loss=0.7525
#   epoch  20  train_loss=0.4837
#   epoch  40  train_loss=0.3993
#   epoch  60  train_loss=0.4015
#   epoch  80  train_loss=0.4090
#   epoch 100  train_loss=0.3897
#   epoch 120  train_loss=0.3753
#   epoch 140  train_loss=0.3764
#   epoch 160  train_loss=0.3930
#   epoch 180  train_loss=0.3873
#   epoch 200  train_loss=0.3804
#   epoch 220  train_loss=0.3926
#   epoch 240  train_loss=0.3864
#   → test_acc=0.802  test_f1=0.800
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.92      0.73      0.82        67
#        Completed (tier 4)       0.69      0.91      0.78        44
#
#                  accuracy                           0.80       111
#                 macro avg       0.81      0.82      0.80       111
#              weighted avg       0.83      0.80      0.80       111
#
#
# ── Fold 3/5  train=443  test=111
#   epoch   1  train_loss=0.7201
#   epoch  20  train_loss=0.4266
#   epoch  40  train_loss=0.3771
#   epoch  60  train_loss=0.3654
#   epoch  80  train_loss=0.3646
#   epoch 100  train_loss=0.3677
#   epoch 120  train_loss=0.3569
#   epoch 140  train_loss=0.3584
#   epoch 160  train_loss=0.3612
#   epoch 180  train_loss=0.3566
#   epoch 200  train_loss=0.3550
#   epoch 220  train_loss=0.3625
#   epoch 240  train_loss=0.3479
#   → test_acc=0.766  test_f1=0.766
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.94      0.66      0.77        67
#        Completed (tier 4)       0.64      0.93      0.76        44
#
#                  accuracy                           0.77       111
#                 macro avg       0.79      0.79      0.77       111
#              weighted avg       0.82      0.77      0.77       111
#
#
# ── Fold 4/5  train=443  test=111
#   epoch   1  train_loss=0.6982
#   epoch  20  train_loss=0.4260
#   epoch  40  train_loss=0.4107
#   epoch  60  train_loss=0.4057
#   epoch  80  train_loss=0.4067
#   epoch 100  train_loss=0.4007
#   epoch 120  train_loss=0.3991
#   epoch 140  train_loss=0.4120
#   epoch 160  train_loss=0.3946
#   epoch 180  train_loss=0.3956
#   epoch 200  train_loss=0.4154
#   epoch 220  train_loss=0.4043
#   epoch 240  train_loss=0.4020
#   → test_acc=0.865  test_f1=0.863
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.95      0.82      0.88        67
#        Completed (tier 4)       0.77      0.93      0.85        44
#
#                  accuracy                           0.86       111
#                 macro avg       0.86      0.88      0.86       111
#              weighted avg       0.88      0.86      0.87       111
#
#
# ── Fold 5/5  train=444  test=110
#   epoch   1  train_loss=0.7077
#   epoch  20  train_loss=0.4465
#   epoch  40  train_loss=0.4328
#   epoch  60  train_loss=0.4195
#   epoch  80  train_loss=0.4060
#   epoch 100  train_loss=0.4075
#   epoch 120  train_loss=0.4001
#   epoch 140  train_loss=0.3976
#   epoch 160  train_loss=0.4055
#   epoch 180  train_loss=0.4052
#   epoch 200  train_loss=0.4149
#   epoch 220  train_loss=0.3920
#   epoch 240  train_loss=0.4138
#   → test_acc=0.855  test_f1=0.853
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.95      0.80      0.87        66
#        Completed (tier 4)       0.76      0.93      0.84        44
#
#                  accuracy                           0.85       110
#                 macro avg       0.85      0.87      0.85       110
#              weighted avg       0.87      0.85      0.86       110
#
#
# ────────────────────────────────────────
#   Fold   Test acc    Test F1
#      1      0.784      0.784
#      2      0.802      0.800
#      3      0.766      0.766
#      4      0.865      0.863
#      5      0.855      0.853
#   Mean      0.814      0.813
#    Std      0.039      0.038

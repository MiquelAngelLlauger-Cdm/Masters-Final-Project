# %% [markdown]
# ## Import Graphs

# %%
import sys, networkx as nx
sys.path.insert(0, "..")   # make models/ importable

G = nx.read_graphml("../graphs/w8/b/KDE_b.graphml")
print(f"Nodes: {G.number_of_nodes()}  Edges: {G.number_of_edges()}")

G12 = nx.read_graphml("../graphs/w12/b/KDE_b.graphml")
print(f"Nodes: {G12.number_of_nodes()}  Edges: {G12.number_of_edges()}")
# Out:
# Nodes: 554  Edges: 1329
# Nodes: 554  Edges: 2088

# %% [markdown]
# ## Validate GCN - w8

# %%
from models.gnn import run

model, data = run(
    G,
    epochs   = 200,
    lr       = 0.01,
    hidden   = 128,
    dropout  = 0.2,
    device   = "cpu",
)
# Out:
# GCN  |  nodes=554  train=354  val=89  test=111
#   epoch   1  train_loss=6.3054  val_loss=62.8397  val_acc=0.404
#   epoch  50  train_loss=0.6906  val_loss=0.6852  val_acc=0.708
#   epoch 100  train_loss=0.6442  val_loss=0.6405  val_acc=0.663
#   epoch 150  train_loss=0.6434  val_loss=0.5665  val_acc=0.719
#   epoch 200  train_loss=0.6157  val_loss=0.5435  val_acc=0.685
#
# Test acc: 0.703
#
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.93      0.55      0.69        67
#        Completed (tier 4)       0.58      0.93      0.71        44
#
#                  accuracy                           0.70       111
#                 macro avg       0.75      0.74      0.70       111
#              weighted avg       0.79      0.70      0.70       111

# %%
from models.gnn import cross_validate

cv_results = cross_validate(
    G,
    k         = 4,
    epochs    = 350,
    lr        = 0.01,
    hidden    = 128,
    dropout   = 0.2,
    device    = "cpu",
)
# Out:
# ── Fold 1/4  train=415  test=139
#   epoch   1  train_loss=5.8591
#   epoch  20  train_loss=0.8214
#   epoch  40  train_loss=0.6920
#   epoch  60  train_loss=0.6919
#   epoch  80  train_loss=0.6857
#   epoch 100  train_loss=0.6844
#   epoch 120  train_loss=0.6707
#   epoch 140  train_loss=0.6669
#   epoch 160  train_loss=0.6666
#   epoch 180  train_loss=0.6675
#   epoch 200  train_loss=0.6474
#   epoch 220  train_loss=0.6735
#   epoch 240  train_loss=0.6533
#   epoch 260  train_loss=0.6627
#   epoch 280  train_loss=0.6593
#   epoch 300  train_loss=0.6494
#   epoch 320  train_loss=0.6387
#   epoch 340  train_loss=0.6312
#   → test_acc=0.676  test_f1=0.676
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.84      0.57      0.68        83
#        Completed (tier 4)       0.57      0.84      0.68        56
#
#                  accuracy                           0.68       139
#                 macro avg       0.70      0.70      0.68       139
#              weighted avg       0.73      0.68      0.68       139
#
#
# ── Fold 2/4  train=415  test=139
#   epoch   1  train_loss=6.8428
#   epoch  20  train_loss=0.8165
#   epoch  40  train_loss=0.7119
#   epoch  60  train_loss=0.6918
#   epoch  80  train_loss=0.6912
#   epoch 100  train_loss=0.6852
#   epoch 120  train_loss=0.6833
#   epoch 140  train_loss=0.6348
#   epoch 160  train_loss=0.6312
#   epoch 180  train_loss=0.6247
#   epoch 200  train_loss=0.6132
#   epoch 220  train_loss=0.5953
#   epoch 240  train_loss=0.5869
#   epoch 260  train_loss=0.5905
#   epoch 280  train_loss=0.5936
#   epoch 300  train_loss=0.5916
#   epoch 320  train_loss=0.5761
#   epoch 340  train_loss=0.5881
#   → test_acc=0.540  test_f1=0.522
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.86      0.29      0.43        84
#        Completed (tier 4)       0.46      0.93      0.61        55
#
#                  accuracy                           0.54       139
#                 macro avg       0.66      0.61      0.52       139
#              weighted avg       0.70      0.54      0.50       139
#
#
# ── Fold 3/4  train=416  test=138
#   epoch   1  train_loss=4.2614
#   epoch  20  train_loss=0.7058
#   epoch  40  train_loss=0.6908
#   epoch  60  train_loss=0.6934
#   epoch  80  train_loss=0.6895
#   epoch 100  train_loss=0.6789
#   epoch 120  train_loss=0.6692
#   epoch 140  train_loss=0.6480
#   epoch 160  train_loss=0.6265
#   epoch 180  train_loss=0.6066
#   epoch 200  train_loss=0.5914
#   epoch 220  train_loss=0.6381
#   epoch 240  train_loss=0.5854
#   epoch 260  train_loss=0.5819
#   epoch 280  train_loss=0.6135
#   epoch 300  train_loss=0.5815
#   epoch 320  train_loss=0.5891
#   epoch 340  train_loss=0.6133
#   → test_acc=0.616  test_f1=0.593
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.67      0.71      0.69        83
#        Completed (tier 4)       0.52      0.47      0.50        55
#
#                  accuracy                           0.62       138
#                 macro avg       0.60      0.59      0.59       138
#              weighted avg       0.61      0.62      0.61       138
#
#
# ── Fold 4/4  train=416  test=138
#   epoch   1  train_loss=8.5296
#   epoch  20  train_loss=0.7262
#   epoch  40  train_loss=0.6960
#   epoch  60  train_loss=0.6937
#   epoch  80  train_loss=0.6938
#   epoch 100  train_loss=0.6927
#   epoch 120  train_loss=0.6925
#   epoch 140  train_loss=0.6931
#   epoch 160  train_loss=0.6928
#   epoch 180  train_loss=0.6936
#   epoch 200  train_loss=0.6932
#   epoch 220  train_loss=0.6933
#   epoch 240  train_loss=0.6940
#   epoch 260  train_loss=0.6934
#   epoch 280  train_loss=0.6931
#   epoch 300  train_loss=0.6934
#   epoch 320  train_loss=0.6923
#   epoch 340  train_loss=0.6931
#   → test_acc=0.399  test_f1=0.285
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.00      0.00      0.00        83
#        Completed (tier 4)       0.40      1.00      0.57        55
#
#                  accuracy                           0.40       138
#                 macro avg       0.20      0.50      0.28       138
#              weighted avg       0.16      0.40      0.23       138
#
#
# ────────────────────────────────────────
#   Fold   Test acc    Test F1
#      1      0.676      0.676
#      2      0.540      0.522
#      3      0.616      0.593
#      4      0.399      0.285
#   Mean      0.558      0.519
#    Std      0.104      0.146

# %% [markdown]
# ## Validate GCN - w12

# %%
from models.gnn import cross_validate

cv_results = cross_validate(
    G12,
    k = 5,
    epochs   = 350,
    lr       = 0.01,
    hidden   = 128,
    dropout  = 0.2,
    device   = "cpu",
)
# Out:
# ── Fold 1/5  train=443  test=111
#   epoch   1  train_loss=3.7533
#   epoch  20  train_loss=0.6927
#   epoch  40  train_loss=0.6980
#   epoch  60  train_loss=0.6688
#   epoch  80  train_loss=0.6391
#   epoch 100  train_loss=0.6291
#   epoch 120  train_loss=0.6274
#   epoch 140  train_loss=0.6315
#   epoch 160  train_loss=0.6039
#   epoch 180  train_loss=0.6045
#   epoch 200  train_loss=0.5801
#   epoch 220  train_loss=0.5712
#   epoch 240  train_loss=0.5556
#   epoch 260  train_loss=0.5869
#   epoch 280  train_loss=0.5571
#   epoch 300  train_loss=0.5587
#   epoch 320  train_loss=0.5636
#   epoch 340  train_loss=0.5679
#   → test_acc=0.748
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.91      0.64      0.75        66
#        Completed (tier 4)       0.63      0.91      0.75        45
#
#                  accuracy                           0.75       111
#                 macro avg       0.77      0.77      0.75       111
#              weighted avg       0.80      0.75      0.75       111
#
#
# ── Fold 2/5  train=443  test=111
#   epoch   1  train_loss=5.4047
#   epoch  20  train_loss=0.9676
#   epoch  40  train_loss=0.6933
#   epoch  60  train_loss=0.6879
#   epoch  80  train_loss=0.6808
#   epoch 100  train_loss=0.6323
#   epoch 120  train_loss=0.5882
#   epoch 140  train_loss=0.5683
#   epoch 160  train_loss=0.5360
#   epoch 180  train_loss=0.5133
#   epoch 200  train_loss=0.5305
#   epoch 220  train_loss=0.5322
#   epoch 240  train_loss=0.5276
#   epoch 260  train_loss=0.5262
#   epoch 280  train_loss=0.5248
#   epoch 300  train_loss=0.5128
#   epoch 320  train_loss=0.5090
#   epoch 340  train_loss=0.5105
#   → test_acc=0.667
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.97      0.46      0.63        67
#        Completed (tier 4)       0.54      0.98      0.70        44
#
#                  accuracy                           0.67       111
#                 macro avg       0.76      0.72      0.66       111
#              weighted avg       0.80      0.67      0.66       111
#
#
# ── Fold 3/5  train=443  test=111
#   epoch   1  train_loss=9.7171
#   epoch  20  train_loss=0.7501
#   epoch  40  train_loss=0.6920
#   epoch  60  train_loss=0.6911
#   epoch  80  train_loss=0.6864
#   epoch 100  train_loss=0.6607
#   epoch 120  train_loss=0.5931
#   epoch 140  train_loss=0.5469
#   epoch 160  train_loss=0.5081
#   epoch 180  train_loss=0.4788
#   epoch 200  train_loss=0.4784
#   epoch 220  train_loss=0.5127
#   epoch 240  train_loss=0.4763
#   epoch 260  train_loss=0.4956
#   epoch 280  train_loss=0.4943
#   epoch 300  train_loss=0.4876
#   epoch 320  train_loss=0.4818
#   epoch 340  train_loss=0.4957
#   → test_acc=0.730
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.91      0.61      0.73        67
#        Completed (tier 4)       0.61      0.91      0.73        44
#
#                  accuracy                           0.73       111
#                 macro avg       0.76      0.76      0.73       111
#              weighted avg       0.79      0.73      0.73       111
#
#
# ── Fold 4/5  train=443  test=111
#   epoch   1  train_loss=5.5201
#   epoch  20  train_loss=0.7956
#   epoch  40  train_loss=0.6863
#   epoch  60  train_loss=0.6942
#   epoch  80  train_loss=0.6609
#   epoch 100  train_loss=0.6204
#   epoch 120  train_loss=0.5863
#   epoch 140  train_loss=0.5154
#   epoch 160  train_loss=0.5326
#   epoch 180  train_loss=0.5030
#   epoch 200  train_loss=0.5157
#   epoch 220  train_loss=0.5028
#   epoch 240  train_loss=0.4960
#   epoch 260  train_loss=0.4763
#   epoch 280  train_loss=0.4872
#   epoch 300  train_loss=0.4952
#   epoch 320  train_loss=0.4952
#   epoch 340  train_loss=0.4856
#   → test_acc=0.685
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.88      0.55      0.68        67
#        Completed (tier 4)       0.57      0.89      0.69        44
#
#                  accuracy                           0.68       111
#                 macro avg       0.72      0.72      0.68       111
#              weighted avg       0.76      0.68      0.68       111
#
#
# ── Fold 5/5  train=444  test=110
#   epoch   1  train_loss=7.8709
#   epoch  20  train_loss=0.7495
#   epoch  40  train_loss=0.6734
#   epoch  60  train_loss=0.6723
#   epoch  80  train_loss=0.6313
#   epoch 100  train_loss=0.5806
#   epoch 120  train_loss=0.5976
#   epoch 140  train_loss=0.5493
#   epoch 160  train_loss=0.5264
#   epoch 180  train_loss=0.5196
#   epoch 200  train_loss=0.5180
#   epoch 220  train_loss=0.5281
#   epoch 240  train_loss=0.5380
#   epoch 260  train_loss=0.5256
#   epoch 280  train_loss=0.5407
#   epoch 300  train_loss=0.5393
#   epoch 320  train_loss=0.5338
#   epoch 340  train_loss=0.5456
#   → test_acc=0.791
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.85      0.79      0.82        66
#        Completed (tier 4)       0.71      0.80      0.75        44
#
#                  accuracy                           0.79       110
#                 macro avg       0.78      0.79      0.79       110
#              weighted avg       0.80      0.79      0.79       110
#
#
# ──────────────────────────────
#   Fold   Test acc
#      1      0.748
#      2      0.667
#      3      0.730
#      4      0.685
#      5      0.791
#   Mean      0.724
#    Std      0.045

# %% [markdown]
# ## Import Graphs

# %%
import sys, networkx as nx
sys.path.insert(0, "..")   # make models/ importable

G = nx.read_graphml("../graphs/w8/b/KDE_b.graphml")
print(f"Nodes: {G.number_of_nodes()}  Edges: {G.number_of_edges()}")

G12 = nx.read_graphml("../graphs/w12/b/KDE_b.graphml")
print(f"Nodes: {G12.number_of_nodes()}  Edges: {G12.number_of_edges()}")
# Out:
# Nodes: 554  Edges: 1329
# Nodes: 554  Edges: 2088

# %% [markdown]
# ## Validate GCN - w8

# %%
from models.gnn import run

model, data = run(
    G,
    epochs   = 300,
    lr       = 0.05,
    hidden   = 128,
    dropout  = 0.2,
    device   = "cpu",
)
# Out:
# GCN  |  nodes=554  train=354  val=89  test=111
#   epoch   1  train_loss=9.9350  val_loss=437.6957  val_acc=0.404
#   epoch  11  train_loss=372.5609  val_loss=52.7560  val_acc=0.404
#   epoch  21  train_loss=44.8557  val_loss=54.8856  val_acc=0.596
#   epoch  31  train_loss=66.0940  val_loss=23.5454  val_acc=0.596
#   epoch  41  train_loss=28.0172  val_loss=9.0341  val_acc=0.404
#   epoch  51  train_loss=7.6618  val_loss=4.2257  val_acc=0.404
#   epoch  61  train_loss=4.1414  val_loss=3.3472  val_acc=0.596
#   epoch  71  train_loss=4.2227  val_loss=2.3480  val_acc=0.404
#   epoch  81  train_loss=2.4397  val_loss=1.7653  val_acc=0.596
#   epoch  91  train_loss=2.2298  val_loss=0.9340  val_acc=0.596
#   epoch 101  train_loss=1.1838  val_loss=0.6584  val_acc=0.584
#   epoch 111  train_loss=0.6943  val_loss=0.7237  val_acc=0.404
#   epoch 121  train_loss=0.7023  val_loss=0.9730  val_acc=0.404
#   epoch 131  train_loss=1.1228  val_loss=0.6972  val_acc=0.596
#   epoch 141  train_loss=0.7417  val_loss=0.6904  val_acc=0.596
#   epoch 151  train_loss=0.7152  val_loss=0.6874  val_acc=0.596
#   epoch 161  train_loss=0.7025  val_loss=0.6877  val_acc=0.596
#   epoch 171  train_loss=0.7065  val_loss=0.6893  val_acc=0.596
#   epoch 181  train_loss=0.7080  val_loss=0.6949  val_acc=0.573
#   epoch 191  train_loss=0.6951  val_loss=0.7110  val_acc=0.404
#   epoch 201  train_loss=0.6994  val_loss=0.7109  val_acc=0.404
#   epoch 211  train_loss=0.6988  val_loss=0.7096  val_acc=0.404
#   epoch 221  train_loss=0.6940  val_loss=0.7075  val_acc=0.404
#   epoch 231  train_loss=0.6974  val_loss=0.7049  val_acc=0.404
#   epoch 241  train_loss=0.6951  val_loss=0.7017  val_acc=0.404
#   epoch 251  train_loss=0.6943  val_loss=0.6985  val_acc=0.404
#   epoch 261  train_loss=0.6967  val_loss=0.6953  val_acc=0.404
#   epoch 271  train_loss=0.6910  val_loss=0.6926  val_acc=0.539
#   epoch 281  train_loss=0.6927  val_loss=0.6905  val_acc=0.596
#   epoch 291  train_loss=0.6960  val_loss=0.6891  val_acc=0.596
#
# Test acc: 0.604
#
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.60      1.00      0.75        67
#        Completed (tier 4)       0.00      0.00      0.00        44
#
#                  accuracy                           0.60       111
#                 macro avg       0.30      0.50      0.38       111
#              weighted avg       0.36      0.60      0.45       111

# %%
from models.gnn import cross_validate

cv_results = cross_validate(
    G,
    k         = 5,
    epochs    = 100,
    lr        = 0.05,
    hidden    = 128,
    dropout   = 0.2,
    device    = "cpu",
)
# Out:
# ── Fold 1/5  train=443  test=111
#   epoch   1  train_loss=22.5018
#   epoch  50  train_loss=0.6932
#   epoch 100  train_loss=0.6931
#   → test_acc=0.595
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.59      1.00      0.75        66
#        Completed (tier 4)       0.00      0.00      0.00        45
#
#                  accuracy                           0.59       111
#                 macro avg       0.30      0.50      0.37       111
#              weighted avg       0.35      0.59      0.44       111
#
#
# ── Fold 2/5  train=443  test=111
#   epoch   1  train_loss=4.5413
#   epoch  50  train_loss=0.6965
#   epoch 100  train_loss=0.6931
#   → test_acc=0.604
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.60      1.00      0.75        67
#        Completed (tier 4)       0.00      0.00      0.00        44
#
#                  accuracy                           0.60       111
#                 macro avg       0.30      0.50      0.38       111
#              weighted avg       0.36      0.60      0.45       111
#
#
# ── Fold 3/5  train=443  test=111
#   epoch   1  train_loss=4.6772
#   epoch  50  train_loss=0.6048
#   epoch 100  train_loss=0.6942
#   → test_acc=0.396
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.00      0.00      0.00        67
#        Completed (tier 4)       0.40      1.00      0.57        44
#
#                  accuracy                           0.40       111
#                 macro avg       0.20      0.50      0.28       111
#              weighted avg       0.16      0.40      0.23       111
#
#
# ── Fold 4/5  train=443  test=111
#   epoch   1  train_loss=9.4054
#   epoch  50  train_loss=0.6934
#   epoch 100  train_loss=0.6930
#   → test_acc=0.396
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.00      0.00      0.00        67
#        Completed (tier 4)       0.40      1.00      0.57        44
#
#                  accuracy                           0.40       111
#                 macro avg       0.20      0.50      0.28       111
#              weighted avg       0.16      0.40      0.23       111
#
#
# ── Fold 5/5  train=444  test=110
#   epoch   1  train_loss=8.6443
#   epoch  50  train_loss=0.7065
#   epoch 100  train_loss=0.6931
#   → test_acc=0.400
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.00      0.00      0.00        66
#        Completed (tier 4)       0.40      1.00      0.57        44
#
#                  accuracy                           0.40       110
#                 macro avg       0.20      0.50      0.29       110
#              weighted avg       0.16      0.40      0.23       110
#
#
# ──────────────────────────────
#   Fold   Test acc
#      1      0.595
#      2      0.604
#      3      0.396
#      4      0.396
#      5      0.400
#   Mean      0.478
#    Std      0.099

# %% [markdown]
# ## Validate GCN - w12

# %%
from models.gnn import run

cv_results = cross_validate(
    G12,
    epochs   = 30,
    lr       = 0.01,
    hidden   = 128,
    dropout  = 0.5,
    device   = "cpu",
)
# Out:
# ── Fold 1/5  train=443  test=111
#   epoch   1  train_loss=9.9298
#   → test_acc=0.595
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.59      1.00      0.75        66
#        Completed (tier 4)       0.00      0.00      0.00        45
#
#                  accuracy                           0.59       111
#                 macro avg       0.30      0.50      0.37       111
#              weighted avg       0.35      0.59      0.44       111
#
#
# ── Fold 2/5  train=443  test=111
#   epoch   1  train_loss=6.1876
#   → test_acc=0.604
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.60      1.00      0.75        67
#        Completed (tier 4)       0.00      0.00      0.00        44
#
#                  accuracy                           0.60       111
#                 macro avg       0.30      0.50      0.38       111
#              weighted avg       0.36      0.60      0.45       111
#
#
# ── Fold 3/5  train=443  test=111
#   epoch   1  train_loss=8.6675
#   → test_acc=0.604
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.60      1.00      0.75        67
#        Completed (tier 4)       0.00      0.00      0.00        44
#
#                  accuracy                           0.60       111
#                 macro avg       0.30      0.50      0.38       111
#              weighted avg       0.36      0.60      0.45       111
#
#
# ── Fold 4/5  train=443  test=111
#   epoch   1  train_loss=14.4919
#   → test_acc=0.396
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.00      0.00      0.00        67
#        Completed (tier 4)       0.40      1.00      0.57        44
#
#                  accuracy                           0.40       111
#                 macro avg       0.20      0.50      0.28       111
#              weighted avg       0.16      0.40      0.23       111
#
#
# ── Fold 5/5  train=444  test=110
#   epoch   1  train_loss=8.4775
#   → test_acc=0.600
#                            precision    recall  f1-score   support
#
# Not completed (tiers 1-3)       0.60      1.00      0.75        66
#        Completed (tier 4)       0.00      0.00      0.00        44
#
#                  accuracy                           0.60       110
#                 macro avg       0.30      0.50      0.38       110
#              weighted avg       0.36      0.60      0.45       110
#
#
# ──────────────────────────────
#   Fold   Test acc
#      1      0.595
#      2      0.604
#      3      0.604
#      4      0.396
#      5      0.600
#   Mean      0.560
#    Std      0.082
